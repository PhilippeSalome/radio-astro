# %%
# Use:                File.rad  scan w1  w2 w3  w4                                                                  
# python removeBase.py gala95-3  10 20 120 150                                                                      
# Give the scanList in the code                                                                                     
#                                                                                                                   
# Plot for all scan the raw data, fit a linear baseline                                                             
# and remove it then average                                                                                        
from numpy import *
from matplotlib import pylab as plt
from matplotlib.pylab import *
from tools import *

# %matplotlib notebook

#PATH="../../../romeo/SRT/Paris3m/"
PATH="../data/SRT/rad/"

filename="gala60-0-070417.rad"
scanList=[0,1,2,3,4,5,6,7]
w1=10
w2=20
w3=120
w4=150

d=data(PATH+filename)



#test alex anti-platforming                                                                                         
for i in range(len(d.scans)):
    if abs(d.Ta[i][55]-d.Ta[i][56])>0.1*mean(d.Ta[i]):
        val=min((d.Ta[i][56]-d.Ta[i][55]),(d.Ta[i][101]-d.Ta[i][102]))
        for j in range(46):
            d.Ta[i][j+56]=d.Ta[i][j+56]-val
#fin test alex                                                                                                      
#marche sur qq exemples                                                                                             
#a ameliorer (critere a prendre notamment)                                                                          

d.baseline2w(scanList, w1, w2, w3, w4)
d.plotallscansChan(scanList)

d.average(scanList)
d.plotAveChan()

d.plotAveVel()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
# Use:           File.rad                                                                                           
# python view.py gala105-2                                                                                          
# Display all the spectra in one plot with subplots                                                                 

from matplotlib import pylab as plt
from matplotlib.pylab import *
# Root directory of the project
ROOT_DIR = os.path.abspath("../")
sys.path.append(ROOT_DIR)  # To find local version of the library
# Now we can import the library and use the function.
from tools import *
PATH="../Data/SRT/rad/"

# %matplotlib inline

filename="gala60-0-070417.rad"

d=data(PATH+filename)

#d.Nchan                                                                                                            
#d.freq0                                                                                                            
#d.velo                                                                                                             

d.scans
print("Elevation "+str(d.El))
print("Azimuth "+str(d.Az))
d.plotscans(d.scans)
plt.show()
# Out:
# Elevation 44.1
# Azimuth 270.2
